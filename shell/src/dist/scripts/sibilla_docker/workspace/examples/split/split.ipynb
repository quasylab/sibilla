# %% [markdown]
# # Importing sibilla

# %%
import sibilla

# %% [markdown]
# # Configuring simulation

# %%
sibilla_runtime = sibilla.SibillaRuntime()
sibilla_runtime.load_module("population")
sibilla_runtime.load_from_file("split.pm")
sibilla_runtime.set_parameter("scale", 1.0)
sibilla_runtime.set_configuration("stateA")
sibilla_runtime.add_all_measures()
sibilla_runtime.set_deadline(100)
sibilla_runtime.set_dt(1.0)
sibilla_runtime.set_replica(100)
# Out:
# Dec 24, 2021 2:15:19 AM it.unicam.quasylab.sibilla.core.simulator.SimulationEnvironment <init>
# INFO: Simulation environment created

# %% [markdown]
# # Starting simulation

# %%
res = sibilla_runtime.simulate("")
# Out:
# Dec 24, 2021 2:15:22 AM it.unicam.quasylab.sibilla.core.simulator.SimulationEnvironment simulate
# INFO: The simulation has concluded with success

# %% [markdown]
# # Plotting Results

# %%
import matplotlib.pyplot as plt

def plot(title, keys, res):
    fig = plt.figure(figsize=(21, 9))
    fig.suptitle(title)
    for i, k in enumerate(keys):
        c_plot = fig.add_subplot(2, 2, i+1)
        c_plot.plot(
            [l[0] for l in res[k]], 
            [l[1] for l in res[k]], 
            label = k
        )
        c_plot.set_ylabel("Mean")
        c_plot.set_xlabel("Sample Time")
        c_plot.legend()
    fig.show()


plot('Population Number', ["#S0", "#S1", "#SU"], res)
plot('Population Percentage', ["%S0", "%S1", "%SU"], res)

# %% [markdown]
# # Saving results

# %%
sibilla_runtime.save("results", "split", "__")
